# %% [markdown]
# # DataSynthesizer Usage (correlated attribute mode)
#
# > This is a quick demo to use DataSynthesizer in correlated attribute mode.
#
# ### Step 1 import packages

# %%
from DataSynthesizer.DataDescriber import DataDescriber
from DataSynthesizer.DataGenerator import DataGenerator
from DataSynthesizer.ModelInspector import ModelInspector
from DataSynthesizer.lib.utils import read_json_file, display_bayesian_network

import pandas as pd

# %% [markdown]
# ### Step 2 user-defined parameteres

# %%
# input dataset
input_data = 'sar.csv'
# location of two output files
mode = 'correlated_attribute_mode'
description_file = f'description.json'
synthetic_data = f'sythetic_data.csv'

# %%
# An attribute is categorical if its domain size is less than this threshold.
# Here modify the threshold to adapt to the domain size of "education" (which is 14 in input dataset).
threshold_value = 20

# specify categorical attributes
categorical_attributes = {'timestamp': True}

# specify which attributes are candidate keys of input dataset.
candidate_keys = {'timestamp': True}

# A parameter in Differential Privacy. It roughly means that removing a row in the input dataset will not 
# change the probability of getting the same output more than a multiplicative difference of exp(epsilon).
# Increase epsilon value to reduce the injected noises. Set epsilon=0 to turn off differential privacy.
epsilon = 1

# The maximum number of parents in Bayesian network, i.e., the maximum number of incoming edges.
degree_of_bayesian_network = 2

# Number of tuples generated in synthetic dataset.
num_tuples_to_generate = 1000 # Here 32561 is the same as input dataset, but it can be set to another number.

# %% [markdown]
# ### Step 3 DataDescriber
#
# 1. Instantiate a DataDescriber.
# 2. Compute the statistics of the dataset.
# 3. Save dataset description to a file on local machine.

# %%
describer = DataDescriber(category_threshold=threshold_value)
describer.describe_dataset_in_correlated_attribute_mode(dataset_file=input_data, 
                                                        epsilon=epsilon, 
                                                        k=degree_of_bayesian_network,
                                                        attribute_to_is_categorical=categorical_attributes,
                                                        attribute_to_is_candidate_key=candidate_keys)
describer.save_dataset_description_to_file(description_file)
# Out:
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT load.runq-sz
# Adding attribute memory.kbdirty
# Adding attribute load.ldavg-1
# Adding attribute memory.kbpgtbl
# Adding attribute memory.kbactive
# Adding attribute io.bwrtn/s
# Adding attribute swap.%swpused
# Adding attribute memory.kbmemfree
# Adding attribute network.txpck/s
# Adding attribute network.txcmp/s
# Adding attribute paging.%vmeff
# Adding attribute disk.rd_sec/s
# Adding attribute memory.kbcommit
# Adding attribute memory.kbanonpg
# Adding attribute network.rxkB/s
# Adding attribute cpu.%iowait
# Adding attribute cpu.%irq
# Adding attribute cpu.%nice
# Adding attribute disk.avgqu-sz
# Adding attribute load.blocked
# Adding attribute disk.svctm
# Adding attribute network.rxmcst/s
# Adding attribute load.ldavg-15
# Adding attribute io.wtps
# Adding attribute load.plist-sz
# Adding attribute cpu.%gnice
# Adding attribute memory.kbslab
# Adding attribute task.proc/s
# Adding attribute network.txkB/s
# Adding attribute memory.kbmemused
# Adding attribute paging.pgsteal/s
# Adding attribute paging.pgpgin/s
# Adding attribute load.ldavg-5
# Adding attribute io.rtps
# Adding attribute memory.%commit
# Adding attribute cpu.%usr
# Adding attribute memory.kbkstack
# Adding attribute memory.kbinact
# Adding attribute memory.kbvmused
# Adding attribute network.rxcmp/s
# Adding attribute swap.kbswpused
# Adding attribute paging.fault/s
# Adding attribute paging.pgscank/s
# Adding attribute swap.kbswpcad
# Adding attribute cpu.%steal
# Adding attribute swap.kbswpfree
# Adding attribute memory.kbbuffers
# Adding attribute intr.intr/s
# Adding attribute cpu.%guest
# Adding attribute paging.pgpgout/s
# Adding attribute paging.pgfree/s
# Adding attribute memory.%memused
# Adding attribute io.tps
# Adding attribute network.%ifutil
# Adding attribute cpu.%soft
# Adding attribute swap.pswpin/s
# Adding attribute task.cswch/s
# Adding attribute disk.wr_sec/s
# Adding attribute paging.majflt/s
# Adding attribute memory.kbavail
# Adding attribute swap.pswpout/s
# Adding attribute cpu.%idle
# Adding attribute cpu.%sys
# Adding attribute disk.await
# Adding attribute paging.pgscand/s
# Adding attribute swap.%swpcad
# Adding attribute disk.tps
# Adding attribute network.rxpck/s
# Adding attribute io.bread/s
# Adding attribute disk.%util
# Adding attribute disk.avgrq-sz
# ========================== BN constructed ==========================

# %%
display_bayesian_network(describer.bayesian_network)
# Out:
# Constructed Bayesian network:
#     memory.kbdirty   has parents ['load.runq-sz'].
#     load.ldavg-1     has parents ['memory.kbdirty', 'load.runq-sz'].
#     memory.kbpgtbl   has parents ['memory.kbdirty', 'load.runq-sz'].
#     memory.kbactive  has parents ['load.ldavg-1', 'memory.kbdirty'].
#     io.bwrtn/s       has parents ['load.ldavg-1', 'load.runq-sz'].
#     swap.%swpused    has parents ['memory.kbdirty', 'load.runq-sz'].
#     memory.kbmemfree has parents ['io.bwrtn/s', 'load.runq-sz'].
#     network.txpck/s  has parents ['memory.kbactive', 'load.runq-sz'].
#     network.txcmp/s  has parents ['network.txpck/s', 'memory.kbpgtbl'].
#     paging.%vmeff    has parents ['swap.%swpused', 'memory.kbpgtbl'].
#     disk.rd_sec/s    has parents ['swap.%swpused', 'memory.kbpgtbl'].
#     memory.kbcommit  has parents ['disk.rd_sec/s', 'memory.kbdirty'].
#     memory.kbanonpg  has parents ['memory.kbactive', 'load.runq-sz'].
#     network.rxkB/s   has parents ['disk.rd_sec/s', 'swap.%swpused'].
#     cpu.%iowait      has parents ['network.rxkB/s', 'memory.kbanonpg'].
#     cpu.%irq         has parents ['paging.%vmeff', 'network.txcmp/s'].
#     cpu.%nice        has parents ['network.rxkB/s', 'load.runq-sz'].
#     disk.avgqu-sz    has parents ['memory.kbmemfree', 'memory.kbdirty'].
#     load.blocked     has parents ['network.txcmp/s', 'io.bwrtn/s'].
#     disk.svctm       has parents ['memory.kbmemfree', 'memory.kbactive'].
#     network.rxmcst/s has parents ['disk.avgqu-sz', 'network.rxkB/s'].
#     load.ldavg-15    has parents ['memory.kbcommit', 'load.ldavg-1'].
#     io.wtps          has parents ['disk.svctm', 'memory.kbpgtbl'].
#     load.plist-sz    has parents ['network.rxkB/s', 'memory.kbcommit'].
#     cpu.%gnice       has parents ['load.ldavg-15', 'swap.%swpused'].
#     memory.kbslab    has parents ['io.wtps', 'network.rxkB/s'].
#     task.proc/s      has parents ['memory.kbmemfree', 'io.bwrtn/s'].
#     network.txkB/s   has parents ['network.rxkB/s', 'paging.%vmeff'].
#     memory.kbmemused has parents ['task.proc/s', 'load.runq-sz'].
#     paging.pgsteal/s has parents ['load.ldavg-15', 'memory.kbdirty'].
#     paging.pgpgin/s  has parents ['load.blocked', 'memory.kbcommit'].
#     load.ldavg-5     has parents ['memory.kbmemfree', 'memory.kbactive'].
#     io.rtps          has parents ['task.proc/s', 'memory.kbmemfree'].
#     memory.%commit   has parents ['paging.pgpgin/s', 'load.runq-sz'].
#     cpu.%usr         has parents ['io.rtps', 'network.rxkB/s'].
#     memory.kbkstack  has parents ['disk.avgqu-sz', 'memory.kbanonpg'].
#     memory.kbinact   has parents ['load.plist-sz', 'disk.svctm'].
#     memory.kbvmused  has parents ['cpu.%irq', 'memory.kbmemfree'].
#     network.rxcmp/s  has parents ['network.txkB/s', 'memory.kbpgtbl'].
#     swap.kbswpused   has parents ['memory.kbactive', 'memory.kbpgtbl'].
#     paging.fault/s   has parents ['cpu.%usr', 'io.wtps'].
#     paging.pgscank/s has parents ['io.wtps', 'disk.svctm'].
#     swap.kbswpcad    has parents ['paging.pgscank/s', 'memory.kbanonpg'].
#     cpu.%steal       has parents ['swap.kbswpcad', 'cpu.%irq'].
#     swap.kbswpfree   has parents ['memory.kbslab', 'network.txpck/s'].
#     memory.kbbuffers has parents ['cpu.%usr', 'load.plist-sz'].
#     intr.intr/s      has parents ['load.blocked', 'memory.kbdirty'].
#     cpu.%guest       has parents ['paging.pgscank/s', 'swap.kbswpused'].
#     paging.pgpgout/s has parents ['paging.pgscank/s', 'memory.kbvmused'].
#     paging.pgfree/s  has parents ['paging.pgpgout/s', 'disk.svctm'].
#     memory.%memused  has parents ['memory.kbinact', 'memory.kbcommit'].
#     io.tps           has parents ['disk.svctm', 'paging.%vmeff'].
#     network.%ifutil  has parents ['memory.kbvmused', 'network.txkB/s'].
#     cpu.%soft        has parents ['network.%ifutil', 'cpu.%gnice'].
#     swap.pswpin/s    has parents ['disk.svctm', 'paging.%vmeff'].
#     task.cswch/s     has parents ['load.blocked', 'memory.kbanonpg'].
#     disk.wr_sec/s    has parents ['cpu.%iowait', 'io.bwrtn/s'].
#     paging.majflt/s  has parents ['memory.kbmemused', 'network.txcmp/s'].
#     memory.kbavail   has parents ['paging.fault/s', 'load.ldavg-15'].
#     swap.pswpout/s   has parents ['cpu.%guest', 'memory.kbslab'].
#     cpu.%idle        has parents ['network.%ifutil', 'network.rxmcst/s'].
#     cpu.%sys         has parents ['memory.kbavail', 'task.cswch/s'].
#     disk.await       has parents ['cpu.%guest', 'network.txpck/s'].
#     paging.pgscand/s has parents ['cpu.%idle', 'network.%ifutil'].
#     swap.%swpcad     has parents ['memory.%commit', 'swap.%swpused'].
#     disk.tps         has parents ['cpu.%guest', 'swap.kbswpused'].
#     network.rxpck/s  has parents ['paging.pgsteal/s', 'paging.%vmeff'].
#     io.bread/s       has parents ['swap.pswpin/s', 'paging.%vmeff'].
#     disk.%util       has parents ['cpu.%steal', 'memory.kbmemused'].
#     disk.avgrq-sz    has parents ['paging.pgsteal/s', 'memory.kbpgtbl'].

# %% [markdown]
# ### Step 4 generate synthetic dataset
#
# 1. Instantiate a DataGenerator.
# 2. Generate a synthetic dataset.
# 3. Save it to local machine.

# %%
generator = DataGenerator()
generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file)
generator.save_synthetic_data(synthetic_data)

# %% [markdown]
# ### Step 5 compare the statistics of input and sythetic data (optional)
#
# The synthetic data is already saved in a file by step 4. The ModelInspector is for a quick test on the similarity between input and synthetic datasets.
#
# #### 5.1 instantiate a ModelInspector.
#
# It needs input dataset, synthetic dataset, and attribute description.

# %%
# Read both datasets using Pandas.
input_df = pd.read_csv(input_data, skipinitialspace=True)
synthetic_df = pd.read_csv(synthetic_data)
# Read attribute description from the dataset description file.
attribute_description = read_json_file(description_file)['attribute_description']

inspector = ModelInspector(input_df, synthetic_df, attribute_description)

# %% [markdown]
# #### 5.2 compare histograms between input and synthetic datasets.

# %%
for attribute in synthetic_df.columns:
    inspector.compare_histograms(attribute)
# Out:
# C:\Users\serap\anaconda3\envs\CBeIntelli_3_8\lib\site-packages\DataSynthesizer\ModelInspector.py:75: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=(15, 5), dpi=120)

# %% [markdown]
# #### 5.3 compare pairwise mutual information

# %%
inspector.mutual_information_heatmap()
